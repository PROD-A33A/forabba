# %% [markdown]
# # My Jupyter notebook on IBM watson studio

# %% [markdown]
# **ABBA ONOJA**
#
# I AM CURRENTLY A STUDENT OF AGRICULTURE IN UNIVERSITY OF ABUJA, NIGERIA

# %% [markdown]
# *I AM INETRESTED IN DATA SCIENCE BECAUSE I AM FASCINATED BY THE ENDLESS POSSIBLITIES THAT CAN BE ACHIEVED WITH DATA SCIENCE AND PRECISION TECHNOLOGY IN THE FIELD OF AGRICULTURE*

# %% [markdown]
# ### THIS FOLLOWING CODE IS A FUNCTION THAT RETURNS AN ITEM WITH THE HIGHEST COUNTABLE VALUE

# %%
NARUTO = max("KAKASHI", "HIDAN")
print(NARUTO)
# Out:
# KAKASHI

# %% [markdown]
#  - NARUTO
#  - SASUKE
#  - KAKASHI
#  - SAKURA
#  - ITACHI
#  - PAIN
#  - MADARA
#  - OBITO

# %% [markdown]
# 1. HASHIRAMA SENJU
# 2. TOBIRAMA SENJU
# 3. HIRUZEN SARUTOBI
# 4. MINATO NAMIKAZE
# 5. TSUNADE SENJU
# 6. KAKASHI HATAKE
# 7. NARUTO UZUMAKI

# %% [markdown]
# | CHARACTER 1 | CHARACTER 2 | WINNER |
# | ----| ----| ----|
# | OBITO       | HIDAN       | OBITO  |
# | NARUTO      | ITACHI      | NARUTO |
